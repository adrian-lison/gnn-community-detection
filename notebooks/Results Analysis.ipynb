# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')

# %%
df = pd.read_csv("../summary/opti_keywords_results.csv")

# %% [markdown]
# # Table data

# %%
#df.groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].max().round(2)

# %%
df.groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].mean().round(2)
# Out:
# split_percentage_train  split_percentage_val  split_percentage_test  net
# 0.04                    0.01                  0.6                    GAT_Net_fast    0.50
#                                                                      GCN_Net         0.41
#                                                                      LGNN_Net        0.39
# 0.08                    0.02                  0.6                    GAT_Net_fast    0.57
#                                                                      GCN_Net         0.49
#                                                                      LGNN_Net        0.48
# 0.16                    0.04                  0.6                    GAT_Net_fast    0.62
#                                                                      GCN_Net         0.57
#                                                                      LGNN_Net        0.52
# 0.32                    0.08                  0.6                    GAT_Net_fast    0.68
#                                                                      GCN_Net         0.61
#                                                                      LGNN_Net        0.57
# Name: Rand-Index_Test, dtype: float64

# %%
df.groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].std().round(2)
# Out:
# split_percentage_train  split_percentage_val  split_percentage_test  net
# 0.04                    0.01                  0.6                    GAT_Net_fast    0.04
#                                                                      GCN_Net         0.06
#                                                                      LGNN_Net        0.06
# 0.08                    0.02                  0.6                    GAT_Net_fast    0.03
#                                                                      GCN_Net         0.05
#                                                                      LGNN_Net        0.04
# 0.16                    0.04                  0.6                    GAT_Net_fast    0.02
#                                                                      GCN_Net         0.05
#                                                                      LGNN_Net        0.04
# 0.32                    0.08                  0.6                    GAT_Net_fast    0.02
#                                                                      GCN_Net         0.04
#                                                                      LGNN_Net        0.03
# Name: Rand-Index_Test, dtype: float64

# %%
#df.groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Mutual Information_Test"].mean().round(2)

# %%
#df.groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Mutual Information_Test"].std().round(2)

# %%
#df.groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Variation of Information_Test"].mean().round(2)

# %%
#df.groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Variation of Information_Test"].std().round(2)

# %%
#Rand-Index
#Helper to print LaTeX tables
a = df.loc[df['net'] == "GCN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].mean().round(2)
b_std = df.loc[df['net'] == "GCN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
a = df.loc[df['net'] == "GAT_Net_fast"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].mean().round(2)
b_std = df.loc[df['net'] == "GAT_Net_fast"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
a = df.loc[df['net'] == "LGNN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].mean().round(2)
b_std = df.loc[df['net'] == "LGNN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Rand-Index_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
# Out:
# & 0.41 $\pm$ 0.06 & 0.49 $\pm$ 0.05 & 0.57 $\pm$ 0.05 & 0.61 $\pm$ 0.04 \\
# & 0.5 $\pm$ 0.04 & 0.57 $\pm$ 0.03 & 0.62 $\pm$ 0.02 & 0.68 $\pm$ 0.02 \\
# & 0.39 $\pm$ 0.06 & 0.48 $\pm$ 0.04 & 0.52 $\pm$ 0.04 & 0.57 $\pm$ 0.03 \\

# %%
#Mutal Information
#Helper to print LaTeX tables
a = df.loc[df['net'] == "GCN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Mutual Information_Test"].mean().round(2)
b_std = df.loc[df['net'] == "GCN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Mutual Information_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
a = df.loc[df['net'] == "GAT_Net_fast"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Mutual Information_Test"].mean().round(2)
b_std = df.loc[df['net'] == "GAT_Net_fast"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Mutual Information_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
a = df.loc[df['net'] == "LGNN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Mutual Information_Test"].mean().round(2)
b_std = df.loc[df['net'] == "LGNN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Mutual Information_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
# Out:
# & 0.42 $\pm$ 0.05 & 0.5 $\pm$ 0.04 & 0.56 $\pm$ 0.04 & 0.6 $\pm$ 0.04 \\
# & 0.51 $\pm$ 0.03 & 0.56 $\pm$ 0.02 & 0.6 $\pm$ 0.02 & 0.65 $\pm$ 0.02 \\
# & 0.45 $\pm$ 0.04 & 0.5 $\pm$ 0.03 & 0.54 $\pm$ 0.02 & 0.58 $\pm$ 0.02 \\

# %%
#Variation of Information
#Helper to print LaTeX tables
a = df.loc[df['net'] == "GCN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Variation of Information_Test"].mean().round(2)
b_std = df.loc[df['net'] == "GCN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Variation of Information_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
a = df.loc[df['net'] == "GAT_Net_fast"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Variation of Information_Test"].mean().round(2)
b_std = df.loc[df['net'] == "GAT_Net_fast"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Variation of Information_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
a = df.loc[df['net'] == "LGNN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Variation of Information_Test"].mean().round(2)
b_std = df.loc[df['net'] == "LGNN_Net"].groupby(["split_percentage_train","split_percentage_val","split_percentage_test","net"])["Variation of Information_Test"].std().round(2)
s = ""
for x in a:
    s += "& " + str(x) + " $\\pm$ " + "{} "
s = s.format(list(b_std)[0],list(b_std)[1],list(b_std)[2],list(b_std)[3])
s += "\\" + "\\"
print(s)
# Out:
# & 1.94 $\pm$ 0.12 & 1.75 $\pm$ 0.12 & 1.56 $\pm$ 0.13 & 1.41 $\pm$ 0.11 \\
# & 1.8 $\pm$ 0.1 & 1.59 $\pm$ 0.07 & 1.45 $\pm$ 0.08 & 1.27 $\pm$ 0.06 \\
# & 1.9 $\pm$ 0.11 & 1.75 $\pm$ 0.1 & 1.61 $\pm$ 0.08 & 1.49 $\pm$ 0.07 \\

# %%
df.head()
# Out:
#    Unnamed: 0                   name  save_logs  save_predictions  \
# 0           0      opti_keywords-412       True              True
# 1           1      opti_keywords-145       True              True
# 2           2      opti_keywords-251       True              True
# 3           3  opti_keywords_gcn-103       True              True
# 4           4      opti_keywords-305       True              True
#
#    save_models  zip_models  verbatim  permutation  repetition  learning_rate  \
# 0         True        True     False            7           3          0.010
# 1         True        True     False            3           4          0.010
# 2         True        True     False            5           4          0.010
# 3         True        True     False            6           4          0.005
# 4         True        True     False            6           2          0.010
#
#    ...  Rand-Index_Train Mutual Information_Train  \
# 0  ...          0.937219                 0.922377
# 1  ...          0.973638                 0.965471
# 2  ...          0.978911                 0.979493
# 3  ...          0.917477                 0.906750
# 4  ...          0.717688                 0.784677
#
#   Variation of Information_Train  Rand-Index_Val Mutual Information_Val  \
# 0                       0.280089        0.782372               0.735074
# 1                       0.119313        0.612998               0.668336
# 2                       0.064940        0.362699               0.401923
# 3                       0.294328        0.417328               0.493123
# 4                       0.659232        0.385230               0.495564
#
#    Variation of Information_Val  Rand-Index_Test  Mutual Information_Test  \
# 0                      0.894840         0.686100                 0.656840
# 1                      0.937913         0.613959                 0.586844
# 2                      1.311831         0.380319                 0.454291
# 3                      1.136186         0.408139                 0.424715
# 4                      1.107448         0.322474                 0.398449
#
#   Variation of Information_Test radius
# 0                      1.252308    NaN
# 1                      1.495417    NaN
# 2                      1.868364    2.0
# 3                      1.982648    NaN
# 4                      1.984969    2.0
#
# [5 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'save_logs', 'save_predictions', 'save_models',
#        'zip_models', 'verbatim', 'permutation', 'repetition', 'learning_rate',
#        'weight_decay', 'net', 'feature', 'skip', 'datetime',
#        'split_percentage_train', 'split_percentage_val',
#        'split_percentage_test', 'loss_function_type', 'loss_function_nclasses',
#        'early_stopping_min', 'early_stopping_wait', 'hidden_size',
#        'hidden_layers', 'num_heads', 'dropout', 'batchnorm', 'residual',
#        'in_feats', 'out_feats', 'Rand-Index_All ', 'Mutual Information_All ',
#        'Variation of Information_All ', 'Rand-Index_Train',
#        'Mutual Information_Train', 'Variation of Information_Train',
#        'Rand-Index_Val', 'Mutual Information_Val',
#        'Variation of Information_Val', 'Rand-Index_Test',
#        'Mutual Information_Test', 'Variation of Information_Test', 'radius'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0  permutation  repetition  learning_rate  weight_decay  \
# count   631.000000   631.000000  631.000000     631.000000  6.310000e+02
# mean    534.453249     5.374010    2.933439       0.008170  1.000000e-02
# std     309.840298     2.886128    1.437151       0.002411  1.423602e-16
# min       0.000000     1.000000    1.000000       0.005000  1.000000e-02
# 25%     267.500000     3.000000    2.000000       0.005000  1.000000e-02
# 50%     537.000000     5.000000    3.000000       0.010000  1.000000e-02
# 75%     805.500000     8.000000    4.000000       0.010000  1.000000e-02
# max    1068.000000    10.000000    5.000000       0.010000  1.000000e-02
#
#        split_percentage_train  split_percentage_val  split_percentage_test  \
# count              631.000000            631.000000           6.310000e+02
# mean                 0.148590              0.037147           6.000000e-01
# std                  0.107007              0.026752           4.666636e-15
# min                  0.040000              0.010000           6.000000e-01
# 25%                  0.040000              0.010000           6.000000e-01
# 50%                  0.080000              0.020000           6.000000e-01
# 75%                  0.160000              0.040000           6.000000e-01
# max                  0.320000              0.080000           6.000000e-01
#
#        early_stopping_min  early_stopping_wait  ...  Rand-Index_Train  \
# count               631.0                631.0  ...        631.000000
# mean                150.0                 80.0  ...          0.880269
# std                   0.0                  0.0  ...          0.104353
# min                 150.0                 80.0  ...          0.408828
# 25%                 150.0                 80.0  ...          0.811048
# 50%                 150.0                 80.0  ...          0.897082
# 75%                 150.0                 80.0  ...          0.971347
# max                 150.0                 80.0  ...          1.000000
#
#        Mutual Information_Train  Variation of Information_Train  \
# count                631.000000                      631.000000
# mean                   0.877628                        0.416477
# std                    0.101569                        0.336762
# min                    0.473587                        0.000000
# 25%                    0.802894                        0.121095
# 50%                    0.895281                        0.366620
# 75%                    0.965461                        0.692204
# max                    1.000000                        1.620155
#
#        Rand-Index_Val  Mutual Information_Val  Variation of Information_Val  \
# count      631.000000              631.000000                    631.000000
# mean         0.570250                0.601773                      1.139364
# std          0.122848                0.101622                      0.251007
# min          0.188514                0.240447                      0.230437
# 25%          0.497252                0.545865                      0.992116
# 50%          0.590964                0.615412                      1.137839
# 75%          0.649870                0.667579                      1.290173
# max          0.866932                0.891858                      1.845895
#
#        Rand-Index_Test  Mutual Information_Test  \
# count       631.000000               631.000000
# mean          0.533743                 0.538506
# std           0.092345                 0.073106
# min           0.275422                 0.302779
# 25%           0.474281                 0.492764
# 50%           0.536819                 0.542081
# 75%           0.602864                 0.592885
# max           0.732291                 0.695447
#
#        Variation of Information_Test  radius
# count                     631.000000   200.0
# mean                        1.631940     2.0
# std                         0.221828     0.0
# min                         1.119342     2.0
# 25%                         1.461499     2.0
# 50%                         1.632704     2.0
# 75%                         1.794788     2.0
# max                         2.196635     2.0
#
# [8 rows x 29 columns]

# %% [markdown]
# # Boxplots

# %%
# !pip install brewer2mpl
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')

large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")
# %matplotlib inline

# Version
print(mpl.__version__)  #> 3.0.0
print(sns.__version__)  #> 0.9.0
# Out:
# 3.1.1
# 0.9.0

# %%
df = df.replace("GAT_Net_fast","GAT")
df = df.replace("LGNN_Net","LGNN")
df = df.replace("GCN_Net","GCN")

# %%
# Draw Plot

plt.figure(figsize=(13,5), dpi= 70)
plt.style.use('ggplot')
sns.boxplot(x='split_percentage_train', y='Rand-Index_Test', data=df, hue='net',showmeans=True,  meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"black"})
axes = plt.gca()
plt.yticks(fontsize=16)
axes.set_xticklabels(["0.04 + 0.01","0.08 + 0.02","0.16 + 0.04","0.32 + 0.08"], fontsize=16)
axes.set_xlabel("Share of training data + share of validation data", fontsize=16)
axes.set_ylabel("Rand Index", fontsize=16)


# Decoration
#plt.title('Box Plot of Highway Mileage by Vehicle Class', fontsize=22)
leg = plt.legend(loc=4, fontsize = 16)
# Get the bounding box of the original legend
bb = leg.get_bbox_to_anchor().inverse_transformed(axes.transAxes)

plt.savefig('../summary/boxplots.pdf',bbox_inches="tight")
plt.show()

# %%
# Draw Plot
plt.figure(figsize=(13,5), dpi= 70)
plt.style.use('ggplot')
sns.boxplot(x='split_percentage_train', y='Mutual Information_Test', data=df, hue='net',showmeans=True,  meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"black"})
axes = plt.gca()
axes.set_xticklabels(["0.04 + 0.01","0.08 + 0.02","0.16 + 0.04","0.32 + 0.08"])
axes.set_xlabel("Share of training data + share of validation data", fontsize=16)
axes.set_ylabel("Mutual Information", fontsize=16)


# Decoration
#plt.title('Box Plot of Highway Mileage by Vehicle Class', fontsize=22)
leg = plt.legend(loc=4, fontsize = 16)
# Get the bounding box of the original legend
bb = leg.get_bbox_to_anchor().inverse_transformed(axes.transAxes)

# Change to location of the legend. 
xOffset = 0
bb.x0 += xOffset
bb.x1 += xOffset
leg.set_bbox_to_anchor(bb, transform = axes.transAxes)

plt.savefig('../summary/boxplots_mi.pdf',bbox_inches="tight")
plt.show()

# %%
# Draw Plot
plt.figure(figsize=(13,5), dpi= 70)
plt.style.use('ggplot')
sns.boxplot(x='split_percentage_train', y='Variation of Information_Test', data=df, hue='net',showmeans=True,  meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"black"})
axes = plt.gca()
axes.set_xticklabels(["0.04 + 0.01","0.08 + 0.02","0.16 + 0.04","0.32 + 0.08"])
axes.set_xlabel("Share of training data + share of validation data", fontsize=16)
axes.set_ylabel("Variation of Information", fontsize=16)


# Decoration
#plt.title('Box Plot of Highway Mileage by Vehicle Class', fontsize=22)
leg = plt.legend()
# Get the bounding box of the original legend
bb = leg.get_bbox_to_anchor().inverse_transformed(axes.transAxes)

# Change to location of the legend. 
xOffset = 0
bb.x0 += xOffset
bb.x1 += xOffset
leg.set_bbox_to_anchor(bb, transform = axes.transAxes)

plt.savefig('../summary/boxplots_vi.pdf',bbox_inches="tight")
plt.show()

# %% [markdown]
# # Loss function

# %%
loss = pd.read_csv("../summary/compare_loss_results.csv")
# Out:
#    Unnamed: 0             name  save_logs  save_predictions  save_models  \
# 0           0  compare_loss-13       True              True        False
# 1           1  compare_loss-33       True              True        False
# 2           2  compare_loss-38       True              True        False
# 3           3  compare_loss-25       True              True        False
# 4           4  compare_loss-18       True              True        False
#
#    zip_models  verbatim  permutation  repetition  learning_rate  ...  \
# 0       False     False            4           1           0.01  ...
# 1       False     False            9           1           0.01  ...
# 2       False     False           10           1           0.01  ...
# 3       False     False            7           1           0.01  ...
# 4       False     False            5           1           0.01  ...
#
#    Variation of Information_All  Rand-Index_Train Mutual Information_Train  \
# 0                       1.137328         0.866459                 0.853543
# 1                       1.242869         0.837946                 0.803470
# 2                       1.048852         0.996536                 0.996055
# 3                       1.207324         0.875205                 0.873625
# 4                       0.962867         0.982282                 0.977339
#
#    Variation of Information_Train Rand-Index_Val  Mutual Information_Val  \
# 0                        0.513480       0.700915                0.700243
# 1                        0.711426       0.635081                0.642987
# 2                        0.014247       0.618693                0.665065
# 3                        0.440588       0.693962                0.637164
# 4                        0.082745       0.777472                0.734255
#
#    Variation of Information_Val  Rand-Index_Test Mutual Information_Test  \
# 0                      1.032584         0.658167                0.614816
# 1                      1.206051         0.624166                0.594890
# 2                      1.181093         0.656027                0.616015
# 3                      1.208213         0.620628                0.584587
# 4                      0.916553         0.685668                0.648149
#
#   Variation of Information_Test
# 0                      1.381184
# 1                      1.452310
# 2                      1.395114
# 3                      1.482519
# 4                      1.282460
#
# [5 rows x 42 columns]

# %%
pd.options.display.max_columns = None
loss.head(10)
# Out:
#    Unnamed: 0             name  save_logs  save_predictions  save_models  \
# 0           0  compare_loss-13       True              True        False
# 1           1  compare_loss-33       True              True        False
# 2           2  compare_loss-38       True              True        False
# 3           3  compare_loss-25       True              True        False
# 4           4  compare_loss-18       True              True        False
# 5           5   compare_loss-7       True              True        False
# 6           6  compare_loss-21       True              True        False
# 7           7   compare_loss-4       True              True        False
# 8           8  compare_loss-34       True              True        False
# 9           9  compare_loss-11       True              True        False
#
#    zip_models  verbatim  permutation  repetition  learning_rate  weight_decay  \
# 0       False     False            4           1           0.01             0
# 1       False     False            9           1           0.01             0
# 2       False     False           10           1           0.01             0
# 3       False     False            7           1           0.01             0
# 4       False     False            5           1           0.01             0
# 5       False     False            2           1           0.01             0
# 6       False     False            6           1           0.01             0
# 7       False     False            2           1           0.01             0
# 8       False     False            9           1           0.01             0
# 9       False     False            3           1           0.01             0
#
#             net   feature   skip             datetime  split_percentage_train  \
# 0  GAT_Net_fast  keywords  False  2020-01-19 16:46:54                    0.32
# 1  GAT_Net_fast  keywords  False  2020-01-19 17:14:05                    0.32
# 2  GAT_Net_fast  keywords  False  2020-01-19 17:23:08                    0.32
# 3  GAT_Net_fast  keywords  False  2020-01-19 17:05:40                    0.32
# 4  GAT_Net_fast  keywords  False  2020-01-19 16:59:09                    0.32
# 5  GAT_Net_fast  keywords  False  2020-01-19 16:37:05                    0.32
# 6  GAT_Net_fast  keywords  False  2020-01-19 16:59:22                    0.32
# 7  GAT_Net_fast  keywords  False  2020-01-19 16:34:58                    0.32
# 8  GAT_Net_fast  keywords  False  2020-01-19 17:19:29                    0.32
# 9  GAT_Net_fast  keywords  False  2020-01-19 16:41:42                    0.32
#
#    split_percentage_val  split_percentage_test loss_function_type  \
# 0                  0.08                    0.6                inv
# 1                  0.08                    0.6                inv
# 2                  0.08                    0.6                inv
# 3                  0.08                    0.6                inv
# 4                  0.08                    0.6                inv
# 5                  0.08                    0.6                nll
# 6                  0.08                    0.6                inv
# 7                  0.08                    0.6                inv
# 8                  0.08                    0.6                inv
# 9                  0.08                    0.6                nll
#
#   loss_function_nclasses  early_stopping_min  early_stopping_wait  \
# 0                      6                 100                   80
# 1                      6                 100                   80
# 2                      7                 100                   80
# 3                      6                 100                   80
# 4                      7                 100                   80
# 5                    all                 100                   80
# 6                      6                 100                   80
# 7                      5                 100                   80
# 8                      7                 100                   80
# 9                    all                 100                   80
#
#    hidden_size  hidden_layers  num_heads  dropout  batchnorm  residual  \
# 0           50              2          1      0.2       True      True
# 1           50              2          1      0.2       True      True
# 2           50              2          1      0.2       True      True
# 3           50              2          1      0.2       True      True
# 4           50              2          1      0.2       True      True
# 5           50              2          1      0.2       True      True
# 6           50              2          1      0.2       True      True
# 7           50              2          1      0.2       True      True
# 8           50              2          1      0.2       True      True
# 9           50              2          1      0.2       True      True
#
#    in_feats  out_feats  Rand-Index_All   Mutual Information_All   \
# 0      1433          7         0.726393                 0.682714
# 1      1433          7         0.690030                 0.656039
# 2      1433          7         0.753640                 0.712999
# 3      1433          7         0.701803                 0.660844
# 4      1433          7         0.780125                 0.737227
# 5      1433          7         0.769702                 0.733707
# 6      1433          7         0.727379                 0.670272
# 7      1433          7         0.569087                 0.526550
# 8      1433          7         0.783619                 0.742400
# 9      1433          7         0.768988                 0.731984
#
#    Variation of Information_All   Rand-Index_Train  Mutual Information_Train  \
# 0                       1.137328          0.866459                  0.853543
# 1                       1.242869          0.837946                  0.803470
# 2                       1.048852          0.996536                  0.996055
# 3                       1.207324          0.875205                  0.873625
# 4                       0.962867          0.982282                  0.977339
# 5                       0.974750          0.965535                  0.956797
# 6                       1.177597          0.917397                  0.889429
# 7                       1.585315          0.678257                  0.659723
# 8                       0.938834          0.970411                  0.964692
# 9                       0.978890          0.994429                  0.992431
#
#    Variation of Information_Train  Rand-Index_Val  Mutual Information_Val  \
# 0                        0.513480        0.700915                0.700243
# 1                        0.711426        0.635081                0.642987
# 2                        0.014247        0.618693                0.665065
# 3                        0.440588        0.693962                0.637164
# 4                        0.082745        0.777472                0.734255
# 5                        0.155704        0.691553                0.645497
# 6                        0.386458        0.672324                0.629727
# 7                        1.113197        0.530415                0.474813
# 8                        0.128214        0.722572                0.707392
# 9                        0.027381        0.709117                0.726451
#
#    Variation of Information_Val  Rand-Index_Test  Mutual Information_Test  \
# 0                      1.032584         0.658167                 0.614816
# 1                      1.206051         0.624166                 0.594890
# 2                      1.181093         0.656027                 0.616015
# 3                      1.208213         0.620628                 0.584587
# 4                      0.916553         0.685668                 0.648149
# 5                      1.240048         0.682294                 0.660089
# 6                      1.254591         0.641691                 0.592543
# 7                      1.681531         0.517224                 0.481214
# 8                      0.997520         0.701948                 0.661572
# 9                      0.970155         0.672291                 0.636150
#
#    Variation of Information_Test
# 0                       1.381184
# 1                       1.452310
# 2                       1.395114
# 3                       1.482519
# 4                       1.282460
# 5                       1.243387
# 6                       1.460801
# 7                       1.740235
# 8                       1.228013
# 9                       1.319495

# %%
loss.groupby(["loss_function_type","loss_function_nclasses"])["Rand-Index_Test"].mean()
# Out:
# loss_function_type  loss_function_nclasses
# inv                 5                         0.533714
#                     6                         0.628045
#                     7                         0.684369
# nll                 all                       0.684749
# Name: Rand-Index_Test, dtype: float64

# %%
loss.groupby(["loss_function_type","loss_function_nclasses"])["Rand-Index_Test"].std()
# Out:
# loss_function_type  loss_function_nclasses
# inv                 5                         0.033607
#                     6                         0.019482
#                     7                         0.020350
# nll                 all                       0.015895
# Name: Rand-Index_Test, dtype: float64

# %%
loss = loss.sort_values(by=["loss_function_type","loss_function_nclasses"])

# %%
loss[["permutation","loss_function_type","loss_function_nclasses","Rand-Index_Test"]]
# Out:
#     permutation loss_function_type loss_function_nclasses  Rand-Index_Test
# 7             2                inv                      5         0.517224
# 14            5                inv                      5         0.539318
# 17            9                inv                      5         0.584899
# 19            7                inv                      5         0.536585
# 26            3                inv                      5         0.551230
# 27            4                inv                      5         0.453379
# 30            1                inv                      5         0.536239
# 33            6                inv                      5         0.554955
# 36            8                inv                      5         0.529808
# 39           10                inv                      5         0.533503
# 0             4                inv                      6         0.658167
# 1             9                inv                      6         0.624166
# 3             7                inv                      6         0.620628
# 6             6                inv                      6         0.641691
# 18            3                inv                      6         0.644600
# 21           10                inv                      6         0.597527
# 23            5                inv                      6         0.650171
# 24            8                inv                      6         0.612724
# 32            1                inv                      6         0.616430
# 37            2                inv                      6         0.614347
# 2            10                inv                      7         0.656027
# 4             5                inv                      7         0.685668
# 8             9                inv                      7         0.701948
# 10            3                inv                      7         0.682150
# 11            6                inv                      7         0.702557
# 13            4                inv                      7         0.724841
# 20            2                inv                      7         0.671524
# 25            7                inv                      7         0.674072
# 28            8                inv                      7         0.678953
# 38            1                inv                      7         0.665955
# 5             2                nll                    all         0.682294
# 9             3                nll                    all         0.672291
# 12            5                nll                    all         0.680808
# 15            7                nll                    all         0.688063
# 16            4                nll                    all         0.704028
# 22            9                nll                    all         0.690450
# 29            1                nll                    all         0.654711
# 31            8                nll                    all         0.679745
# 34           10                nll                    all         0.682939
# 35            6                nll                    all         0.712161

# %%
loss.columns
# Out:
# Index(['Unnamed: 0', 'name', 'save_logs', 'save_predictions', 'save_models',
#        'zip_models', 'verbatim', 'permutation', 'repetition', 'learning_rate',
#        'weight_decay', 'net', 'feature', 'skip', 'datetime',
#        'split_percentage_train', 'split_percentage_val',
#        'split_percentage_test', 'loss_function_type', 'loss_function_nclasses',
#        'early_stopping_min', 'early_stopping_wait', 'hidden_size',
#        'hidden_layers', 'num_heads', 'dropout', 'batchnorm', 'residual',
#        'in_feats', 'out_feats', 'Rand-Index_All ', 'Mutual Information_All ',
#        'Variation of Information_All ', 'Rand-Index_Train',
#        'Mutual Information_Train', 'Variation of Information_Train',
#        'Rand-Index_Val', 'Mutual Information_Val',
#        'Variation of Information_Val', 'Rand-Index_Test',
#        'Mutual Information_Test', 'Variation of Information_Test'],
#       dtype='object')

# %% [markdown]
# # Epoch Development

# %%
df = pd.read_csv("../logs/opti_keywords-349.csv")

# %%
df = df[df["epoch"] <= 40]

# %%
df["rand_test"].max()
# Out:
# 0.7013859998909703

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

fig, ax = plt.subplots(figsize=(10,5), dpi= 90)

ax.plot(list(df["epoch"]), list(df["rand_train"]), label = "Rand Index on training data")
ax.plot(list(df["epoch"]), list(df["rand_test"]), label = "Rand Index on testing data")
ax.plot(list(df["epoch"]), list(df["rand_val"]), label = "Rand Index on validation data")
ax.legend(fontsize=12, loc= 4)

def annot_max(x,y,locx, locy, ax=None):
    xmax = x[np.argmax(y)]
    ymax = y.max()
    text= "x={:.3f}, y={:.3f}".format(xmax, ymax)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.62)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=60")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmax, ymax), xytext=(locx,locy), **kw)
    
def annot_max2(x,y,locx, locy, ax=None):
    xmax = x[np.argmax(y)]
    ymax = y.max()
    text= "Epoch {}, RI: {:.3f}".format(xmax, ymax)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.62)
    arrowprops=dict(arrowstyle="->")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmax, ymax), xytext=(locx,locy), **kw)

plt.yticks(np.arange(0, 1, 0.1)) 

annot_max2(list(df["epoch"]), df["rand_train"],0.93,0.5)
annot_max2(list(df["epoch"]), df["rand_test"],0.75,0.40)
annot_max2(list(df["epoch"]), df["rand_val"],0.45,0.3)

ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Rand Index (RI)", fontsize=12)

plt.savefig('../summary/rand_index_dev.pdf',bbox_inches="tight")
plt.show()
# Out:
# C:\Nospace\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:56: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# # Correlation of performance measures

# %%
import pandas as pd
df = pd.read_csv("../summary/opti_keywords_results.csv")

# %%
df[["Rand-Index_Test", "Mutual Information_Test", "Variation of Information_Test"]].corr()
# Out:
#                                Rand-Index_Test  Mutual Information_Test  \
# Rand-Index_Test                       1.000000                 0.971805
# Mutual Information_Test               0.971805                 1.000000
# Variation of Information_Test        -0.942229                -0.977502
#
#                                Variation of Information_Test
# Rand-Index_Test                                    -0.942229
# Mutual Information_Test                            -0.977502
# Variation of Information_Test                       1.000000

# %% [markdown]
# # Hyperparameters

# %%
df.groupby(["net"])["learning_rate"].unique()
# Out:
# net
# GAT_Net_fast     [0.01]
# GCN_Net         [0.005]
# LGNN_Net         [0.01]
# Name: learning_rate, dtype: object

# %%
df.groupby(["net"])["weight_decay"].unique()
# Out:
# net
# GAT_Net_fast    [0.01]
# GCN_Net         [0.01]
# LGNN_Net        [0.01]
# Name: weight_decay, dtype: object

# %%
df.groupby(["net"])["loss_function_type"].unique()
# Out:
# net
# GAT_Net_fast    [nll]
# GCN_Net         [nll]
# LGNN_Net        [nll]
# Name: loss_function_type, dtype: object

# %%
df.groupby(["net"])["loss_function_nclasses"].unique()
# Out:
# net
# GAT_Net_fast    [all]
# GCN_Net         [all]
# LGNN_Net        [all]
# Name: loss_function_nclasses, dtype: object

# %%
df.groupby(["net"])["hidden_size"].unique()
# Out:
# net
# GAT_Net_fast     [50]
# GCN_Net         [100]
# LGNN_Net        [100]
# Name: hidden_size, dtype: object

# %%
df.groupby(["net"])["hidden_layers"].unique()
# Out:
# net
# GAT_Net_fast    [2]
# GCN_Net         [1]
# LGNN_Net        [1]
# Name: hidden_layers, dtype: object

# %%
df.groupby(["net"])["num_heads"].unique()
# Out:
# net
# GAT_Net_fast    [1.0]
# GCN_Net         [nan]
# LGNN_Net        [nan]
# Name: num_heads, dtype: object

# %%
df.groupby(["net"])["dropout"].unique()
# Out:
# net
# GAT_Net_fast    [0.2]
# GCN_Net         [0.2]
# LGNN_Net        [0.2]
# Name: dropout, dtype: object

# %%
df.groupby(["net"])["batchnorm"].unique()
# Out:
# net
# GAT_Net_fast     [True]
# GCN_Net         [False]
# LGNN_Net        [False]
# Name: batchnorm, dtype: object

# %%
df.groupby(["net"])["residual"].unique()
# Out:
# net
# GAT_Net_fast    [False]
# GCN_Net           [nan]
# LGNN_Net          [nan]
# Name: residual, dtype: object

# %%
df.groupby(["net"])["early_stopping_min"].unique()
# Out:
# net
# GAT_Net_fast    [150]
# GCN_Net         [150]
# LGNN_Net        [150]
# Name: early_stopping_min, dtype: object

# %%
df.groupby(["net"])["early_stopping_wait"].unique()
# Out:
# net
# GAT_Net_fast    [80]
# GCN_Net         [80]
# LGNN_Net        [80]
# Name: early_stopping_wait, dtype: object
